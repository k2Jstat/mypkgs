# %%
from sklearn.datasets import load_boston,load_breast_cancer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import joblib

# %%
from pandasxtend.eda.stats import KL_Divergence,Summary
from pandasxtend.eda.visualization import AllPlot

# %%
#load_breast_cancer()

# %%
X = load_boston()["data"]
y = load_boston()["target"]
cols = load_boston()["feature_names"]

X_df = pd.DataFrame(X)
X_df.columns = cols

# %%
np.random.seed(1111)
X_df["rand"] = np.random.choice([1,2,3,4,5],X_df.shape[0])

# %%
dic_date = {1:"19900101",2:"20000202",3:"20100303",4:"20200404",5:np.nan}
dic_str = {1:"A",2:"BB",3:"CCC",4:"DDDD",5:"EEEEE"}

X_df["sample_datetime"] = pd.to_datetime(X_df["rand"].map(dic_date))
X_df["sample_str"] = X_df["rand"].map(dic_str)

# %%
X_df["flg_over_age"] = (X_df["AGE"] >= X_df["AGE"].mean()).astype(int)

# %%
bun_df = X_df.copy()
bun_df["target"] = y

# %%
mean_target = bun_df["target"].mean()
bun_df["flg_target"] = (bun_df["target"] >= mean_target).astype(int)
#bun_df["flg_target"] = (bun_df["target"] < mean_target)

# %%
bun_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  rand sample_datetime sample_str  flg_over_age  \
# 0     15.3  396.90   4.98     5             NaT      EEEEE             0
# 1     17.8  396.90   9.14     2      2000-02-02         BB             1
# 2     17.8  392.83   4.03     5             NaT      EEEEE             0
# 3     18.7  394.63   2.94     3      2010-03-03        CCC             0
# 4     18.7  396.90   5.33     5             NaT      EEEEE             0
#
#    target  flg_target
# 0    24.0           1
# 1    21.6           0
# 2    34.7           1
# 3    33.4           1
# 4    36.2           1

# %%
bun_df2 = bun_df.sample(n = 10000000,replace = True).copy()
bun_df2.reset_index(inplace = True,drop = True)

# %%
bun_df2.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'rand', 'sample_datetime', 'sample_str',
#        'flg_over_age', 'target', 'flg_target'],
#       dtype='object')

# %%
summary1 = Summary(bun_df2)
summary1.run()
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:   12.5s finished
#         column_name   format     count missing_count unique_count  \
# 0              CRIM  numeric  10000000             0          504
# 1                ZN  numeric  10000000             0           26
# 2             INDUS  numeric  10000000             0           76
# 3              CHAS  numeric  10000000             0            2
# 4               NOX  numeric  10000000             0           81
# 5                RM  numeric  10000000             0          446
# 6               AGE  numeric  10000000             0          356
# 7               DIS  numeric  10000000             0          412
# 8               RAD  numeric  10000000             0            9
# 9               TAX  numeric  10000000             0           66
# 10          PTRATIO  numeric  10000000             0           46
# 11                B  numeric  10000000             0          357
# 12            LSTAT  numeric  10000000             0          455
# 13             rand  numeric  10000000             0            5
# 14  sample_datetime  numeric   7668234       2331766            5
# 15       sample_str  strings  10000000             0            5
# 16     flg_over_age  numeric  10000000             0            2
# 17           target  numeric  10000000             0          229
# 18       flg_target  numeric  10000000             0            2
#
#                     min     p01      p05                  p25  \
# 5                       0.702016    6.127    59561                6.219
# 6                       28.12492    100.0   851015                100.0
# 7                       2.103165   3.4952    98445               2.0048
# 8                       8.699614     24.0  2609657                 24.0
# 9                     168.376873    666.0  2609657                666.0
# 10                      2.163257     20.2  2767671                 20.2
# 11                     91.175077    396.9  2392075               395.69
# 12                      7.133643     6.36    59823                16.59
# 13                      1.440563        5  2331766                    3
# 14  4206 days 12:52:28.380417088      NaT  2331766  2010-03-03 00:00:00
# 15                           NaN    EEEEE  2331766                  CCC
# 16                       0.49369        1  5791845                    1
# 17                      9.190813     50.0   316907                 18.4
# 18                      0.492412        0  5867781                    0
#
#                   tail1
# 0               0.29819
# 1                   0.0
# 2                   6.2
# 3                   0.0
# 4                 0.504
# 5                 7.686
# 6                  17.0
# 7                3.3751
# 8                   8.0
# 9                 307.0
# 10                 17.4
# 11               377.51
# 12                 3.92
# 13                    2
# 14  2000-02-02 00:00:00
# 15                   BB
# 16                    0
# 17                 46.7
# 18                    1

# %%
#summary1.to_csv()

# %%
KL1 = KL_Divergence(bun_df2,"flg_target",base_label=1)
KL1.run()
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:   13.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:    0.2s finished
#             columns  base  KL_Divergence
# 0            target     1       15.30404
# 1             LSTAT     1        2.50368
# 2                ZN     1        2.45920
# 3               AGE     1        1.96111
# 4             INDUS     1        0.93019
# 5               TAX     1        0.64853
# 6                 B     1        0.30633
# 7              CRIM     1        0.25507
# 8              CHAS     1            NaN
# 9               NOX     1            NaN
# 10               RM     1            NaN
# 11              DIS     1            NaN
# 12              RAD     1            NaN
# 13          PTRATIO     1            NaN
# 14             rand     1            NaN
# 15  sample_datetime     1            NaN
# 16     flg_over_age     1            NaN
# 17       flg_target     1            NaN

# %%
KL1.plot()

# %%
aplt = AllPlot(bun_df2,sample_size=10000)
#aplt = all_plot(bun_df)

# %%
aplt.Histgram()

# %%
aplt.LinearityCheckBinaryTarget(target_="flg_over_age")

# %%
aplt.LinearityCheckBinaryTarget(target_="flg_target")

# %%
aplt.CountByCategory()

# %%
aplt.Boxplot()

# %%
aplt.CountByDatetime()

# %%
aplt.MeanByTimeseries()

# %%
import scipy.stats as stats

# %%
stats.probplot(np.random.randn(100))
plt.show()

# %%
def qqplot(dist):
    plt.hist(dist, bins=30)
    plt.show()
    stats.probplot(dist, dist="norm", plot=plt)
    plt.show()

# 正規分布
qqplot(np.random.randn(10000))

# %%
dist = np.random.randn(10000)

# %%
from scipy.stats.mstats import describe
ma = np.ma.array(range(6), mask=[0, 0, 0, 1, 1, 1])
aa = describe(ma)

# %%
#plt.hist(dist, bins=30)
#plt.show()
stats.probplot(dist, dist="norm", plot=plt,fit = False)
#stats.probplot(dist, dist=stats.gamma, plot=plt,fit = False)
plt.show()
