# %%
from sklearn.datasets import load_boston,load_breast_cancer
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
#import joblib

# %%
from pandasxtend.eda.stats import KL_Divergence,Summary
from pandasxtend.eda.visualization import AllPlot

# %%
#load_breast_cancer()

# %%
X = load_boston()["data"]
y = load_boston()["target"]
cols = load_boston()["feature_names"]

X_df = pd.DataFrame(X)
X_df.columns = cols

# %%
np.random.seed(1111)
X_df["rand"] = np.random.choice([1,2,3,4,5],X_df.shape[0])

# %%
dic_date = {1:"19900101",2:"20000202",3:"20100303",4:"20200404",5:np.nan}
dic_str = {1:"A",2:"BB",3:"CCC",4:"DDDD",5:"EEEEE"}

X_df["sample_datetime"] = pd.to_datetime(X_df["rand"].map(dic_date))
X_df["sample_str"] = X_df["rand"].map(dic_str)

# %%
X_df["flg_over_age"] = (X_df["AGE"] >= X_df["AGE"].mean()).astype(int)

# %%
bun_df = X_df.copy()
bun_df["target"] = y

# %%
mean_target = bun_df["target"].mean()
bun_df["flg_target"] = (bun_df["target"] >= mean_target).astype(int)
#bun_df["flg_target"] = (bun_df["target"] < mean_target)

# %%
bun_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  rand sample_datetime sample_str  flg_over_age  \
# 0     15.3  396.90   4.98     5             NaT      EEEEE             0
# 1     17.8  396.90   9.14     2      2000-02-02         BB             1
# 2     17.8  392.83   4.03     5             NaT      EEEEE             0
# 3     18.7  394.63   2.94     3      2010-03-03        CCC             0
# 4     18.7  396.90   5.33     5             NaT      EEEEE             0
#
#    target  flg_target
# 0    24.0           1
# 1    21.6           0
# 2    34.7           1
# 3    33.4           1
# 4    36.2           1

# %%
summary1 = Summary(bun_df)
summary1.run()
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:    1.7s finished
#         column_name   format count missing_count unique_count  \
# 0              CRIM  numeric   506             0          504
# 1                ZN  numeric   506             0           26
# 2             INDUS  numeric   506             0           76
# 3              CHAS  numeric   506             0            2
# 4               NOX  numeric   506             0           81
# 5                RM  numeric   506             0          446
# 6               AGE  numeric   506             0          356
# 7               DIS  numeric   506             0          412
# 8               RAD  numeric   506             0            9
# 9               TAX  numeric   506             0           66
# 10          PTRATIO  numeric   506             0           46
# 11                B  numeric   506             0          357
# 12            LSTAT  numeric   506             0          455
# 13             rand  numeric   506             0            5
# 14  sample_datetime  numeric   388           118            5
# 15       sample_str  strings   506             0            5
# 16     flg_over_age  numeric   506             0            2
# 17           target  numeric   506             0          229
# 18       flg_target  numeric   506             0            2
#
#                     min      p01       p05                  p25  \
# 0               0.00632  0.01361   0.02791             0.082045
# 1                   0.0      0.0       0.0                  0.0
# 2                  0.46   1.2535      2.18                 5.19
# 3                   0.0      0.0       0.0                  0.0
# 4                 0.385    0.398   0.40925                0.449
# 5                 3.561  4.52445     5.314               5.8855
# 6                   2.9     6.61    17.725               45.025
# 7                1.1296  1.20654  1.461975             2.100175
# 8                   1.0      1.0       2.0                  4.0
# 9                 187.0    188.0     222.0                279.0
# 10                 12.6     13.0      14.7                 17.4
# 11                 0.32     6.73     84.59             375.3775
# 12                 1.73    2.883    3.7075                 6.95
# 13                    1      1.0       1.0                  2.0
# 14  1990-01-01 00:00:00      NaT       NaT  1990-01-01 00:00:00
# 15                  NaN      NaN       NaN                  NaN
# 16                    0      0.0       0.0                  0.0
# 17                  5.0     7.01      10.2               17.025
# 18                    0      0.0       0.0                  0.0
#
#                     p50                  p75                  p95  \
# 0               0.25651             3.677083             15.78915
# 1                   0.0                 12.5                 80.0
# 2                  9.69                 18.1                21.89
# 3                   0.0                  0.0                  1.0
# 4                 0.538                0.624                 0.74
# 5                6.2085               6.6235               7.5875
# 6                  77.5               94.075                100.0
# 7               3.20745             5.188425               7.8278
# 8                   5.0                 24.0                 24.0
# 9                 330.0                666.0                666.0
# 10                19.05                 20.2                 21.0
# 11               391.44              396.225                396.9
# 12                11.36               16.955              26.8075
# 13                  3.0                  4.0                  5.0
# 14  2000-02-02 00:00:00  2010-03-03 00:00:00  2020-04-04 00:00:00
# 15                  NaN                  NaN                  NaN
# 16                  1.0                  1.0                  1.0
# 17                 21.2                 25.0                 43.4
# 18                  0.0                  1.0                  1.0
#
#                     p99                  max                           mean  \
# 0              41.37033              88.9762                       3.613524
# 1                  90.0                100.0                      11.363636
# 2                 25.65                27.74                      11.136779
# 3                   1.0                  1.0                        0.06917
# 4                 0.871                0.871                       0.554695
# 5                 8.335                 8.78                       6.284634
# 6                 100.0                100.0                      68.574901
# 7               9.22277              12.1265                       3.795043
# 8                  24.0                 24.0                       9.549407
# 9                 666.0                711.0                     408.237154
# 10                 21.2                 22.0                      18.455534
# 11                396.9                396.9                     356.674032
# 12              33.9185                37.97                      12.653063
# 13                  5.0                    5                       3.120553
# 14  2020-04-04 00:00:00  2020-04-04 00:00:00  2005-08-15 15:01:51.340206208
# 15                  NaN                  NaN                            NaN
# 16                  1.0                    1                       0.579051
# 17                 50.0                 50.0                      22.532806
# 18                  1.0                    1                       0.413043
#
#                              std      top freq    head1                tail1
# 0                       8.601545  0.01501    2  0.00632              0.04741
# 1                      23.322453      0.0  372     18.0                  0.0
# 2                       6.860353     18.1  132     2.31                11.93
# 3                       0.253994      0.0  471      0.0                  0.0
# 4                       0.115878    0.538   23    0.538                0.573
# 5                       0.702617    6.167    3    6.575                 6.03
# 6                      28.148861    100.0   43     65.2                 80.8
# 7                        2.10571   3.4952    5     4.09                2.505
# 8                       8.707259     24.0  132      1.0                  1.0
# 9                     168.537116    666.0  132    296.0                273.0
# 10                      2.164946     20.2  140     15.3                 21.0
# 11                     91.294864    396.9  121    396.9                396.9
# 12                      7.141062     8.05    3     4.98                 7.88
# 13                      1.441703        5  118        5                    4
# 14  4212 days 05:40:02.126355392      NaT  118      NaT  2020-04-04 00:00:00
# 15                           NaN    EEEEE  118    EEEEE                 DDDD
# 16                        0.4942        1  293        0                    1
# 17                      9.197104     50.0   16     24.0                 11.9
# 18                      0.492868        0  297        1                    0

# %%
#summary1.to_csv()

# %%
KL1 = KL_Divergence(bun_df,"flg_target",base_label=1)
KL1.run()
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:    0.2s finished
#             columns  base  KL_Divergence
# 0            target     1       19.73150
# 1                ZN     1        2.28355
# 2             LSTAT     1        1.82081
# 3               AGE     1        1.63844
# 4             INDUS     1        0.61216
# 5               TAX     1        0.37910
# 6               DIS     1        0.28534
# 7                 B     1        0.19443
# 8              CRIM     1        0.17336
# 9               RAD     1        0.06020
# 10             CHAS     1            NaN
# 11              NOX     1            NaN
# 12               RM     1            NaN
# 13          PTRATIO     1            NaN
# 14             rand     1            NaN
# 15  sample_datetime     1            NaN
# 16     flg_over_age     1            NaN
# 17       flg_target     1            NaN

# %%
KL1.plot()

# %%
aplt = AllPlot(bun_df)
#aplt = all_plot(bun_df)

# %%
aplt.Histgram()

# %%
aplt.LinearityCheckBinaryTarget(target_="flg_over_age")

# %%
aplt.LinearityCheckBinaryTarget(target_="flg_target")

# %%
aplt.CountByCategory()

# %%
aplt.Boxplot()

# %%
aplt.CountByDatetime()

# %%
aplt.MeanByTimeseries()
